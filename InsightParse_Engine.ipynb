# %% [markdown]
# # Welcome to Colab!

# %% [markdown]
# ## Google Colab is available in VS Code!
# ![logo.webp](data:image/webp;base64,...)
#
# Try the new [Google Colab extension](https://marketplace.visualstudio.com/items?itemName=Google.colab) for Visual Studio Code. You can get up and running in just a few clicks:
#
# *  In VS Code, open the ***Extensions*** view and search for 'Google Colab' to install.
# *  Open the kernel selector by creating or opening any `.ipynb` notebook file in your local workspace and either running a cell or clicking the ***Select Kernel*** button in the top right.
# *  Click ***Colab*** and then select your desired runtime, sign in with your Google account, and you're all set!
#
# See more details in our [announcement blog here](https://developers.googleblog.com/google-colab-is-coming-to-vs-code).

# %% [markdown]
# ## 🎁 Free Pro Plan for Gemini & Colab for US College Students 🎓
#
# Get more access to our most accurate model Gemini 3 Pro for advanced coding, complex research, and innovative projects, backed by Colab’s dedicated high-compute resources for data science and machine learning.
#
# Get the Gemini free offer at [gemini.google/students](https://gemini.google/students?utm_source=colab&utm_medium=banner&utm_campaign=students_xpa_us-colab-banner).
# Get the Colab free offer at [colab.research.google.com/signup](https://colab.research.google.com/signup).
# Terms Apply.

# %% [markdown]
# ## Access popular AI models via Google-Colab-AI Without an API Key
# All users have access to most popular LLMs via the `google-colab-ai` Python library, and paid users have access to a wider selection of models. For more details, refer to the [getting started with google colab ai](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/Getting_started_with_google_colab_ai.ipynb).

# %%
from google.colab import ai
response = ai.generate_text("What is the capital of France?")

# %% [markdown]
# ## Explore the Gemini API
# The Gemini API gives you access to Gemini models created by Google DeepMind. Gemini models are built from the ground up to be multimodal, so you can reason seamlessly across text, images, code, and audio.
#
# **How to get started?**
# *  Go to [Google AI Studio](https://aistudio.google.com/) and log in with your Google account.
# *  [Create an API key](https://aistudio.google.com/app/apikey).
# * Use a quickstart for [Python](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Get_started.ipynb), or call the REST API using [curl](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/rest/Prompting_REST.ipynb).
#
# **Discover Gemini's advanced capabilities**
# *  Play with Gemini [multimodal outputs](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Image-out.ipynb), mixing text and images in an iterative way.
# *  Discover the [multimodal Live API](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Get_started_LiveAPI.ipynb ) (demo [here](https://aistudio.google.com/live)).
# *  Learn how to [analyze images and detect items in your pictures](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Spatial_understanding.ipynb") using Gemini (bonus, there's a [3D version](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Spatial_understanding_3d.ipynb) as well!).
# *  Unlock the power of [Gemini thinking model](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Get_started_thinking.ipynb), capable of solving complex task with its inner thoughts.
#
# **Explore complex use cases**
# *  Use [Gemini grounding capabilities](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Search_grounding_for_research_report.ipynb) to create a report on a company based on what the model can find on internet.
# *  Extract [invoices and form data from PDF](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Pdf_structured_outputs_on_invoices_and_forms.ipynb) in a structured way.
# *  Create [illustrations based on a whole book](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Book_illustration.ipynb) using Gemini large context window and Imagen.
#
# To learn more, check out the [Gemini cookbook](https://github.com/google-gemini/cookbook) or visit the [Gemini API documentation](https://ai.google.dev/docs/).

# %% [markdown]
# Colab now has AI features powered by [Gemini](https://gemini.google.com). The video below provides information on how to use these features, whether you're new to Python, or a seasoned veteran.
#
# <center>
#   <a href="https://www.youtube.com/watch?v=V7RXyqFUR98" target="_blank">
#   <img alt='Thumbnail for a video showing 3 AI-powered Google Colab features' src="data:image/png;base64,..." height="188" width="336">
#   </a>
# </center>

# %% [markdown]
# <div class="markdown-google-sans">
#   <h2>What is Colab?</h2>
# </div>
#
# Colab, or "Colaboratory", allows you to write and execute Python in your browser, with
# - Zero configuration required
# - Access to GPUs free of charge
# - Easy sharing
#
# Whether you're a **student**, a **data scientist** or an **AI researcher**, Colab can make your work easier. Watch [Introduction to Colab](https://www.youtube.com/watch?v=inN8seMm7UI) or [Colab Features You May Have Missed](https://www.youtube.com/watch?v=rNgswRZ2C1Y) to learn more, or just get started below!

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## **Getting started**
# </div>
#
# The document you are reading is not a static web page, but an interactive environment called a **Colab notebook** that lets you write and execute code.
#
# For example, here is a **code cell** with a short Python script that computes a value, stores it in a variable, and prints the result:

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day

# %% [markdown]
# To execute the code in the above cell, select it with a click and then either press the play button to the left of the code, or use the keyboard shortcut "Command/Ctrl+Enter". To edit the code, just click the cell and start editing.
#
# Variables that you define in one cell can later be used in other cells:

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week

# %% [markdown]
# Colab notebooks allow you to combine **executable code** and **rich text** in a single document, along with **images**, **HTML**, **LaTeX** and more. When you create your own Colab notebooks, they are stored in your Google Drive account. You can easily share your Colab notebooks with co-workers or friends, allowing them to comment on your notebooks or even edit them. To learn more, see [Overview of Colab](/notebooks/basic_features_overview.ipynb). To create a new Colab notebook you can use the File menu above, or use the following link: [create a new Colab notebook](http://colab.research.google.com#create=true).
#
# Colab notebooks are Jupyter notebooks that are hosted by Colab. To learn more about the Jupyter project, see [jupyter.org](https://www.jupyter.org).

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Data science
# </div>
#
# With Colab you can harness the full power of popular Python libraries to analyze and visualize data. The code cell below uses **numpy** to generate some random data, and uses **matplotlib** to visualize it. To edit the code, just click the cell and start editing.

# %% [markdown]
# You can import your own data into Colab notebooks from your Google Drive account, including from spreadsheets, as well as from Github and many other sources. To learn more about importing data, and how Colab can be used for data science, see the links below under [Working with Data](#working-with-data).

# %%
import numpy as np
import IPython.display as display
from matplotlib import pyplot as plt
import io
import base64

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

fig = plt.figure(figsize=(4, 3), facecolor='w')
plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)
plt.title("Sample Visualization", fontsize=10)

data = io.BytesIO()
plt.savefig(data)
image = F"data:image/png;base64,{base64.b64encode(data.getvalue()).decode()}"
alt = "Sample Visualization"
display.display(display.Markdown(F"""![{alt}]({image})"""))
plt.close(fig)

# %% [markdown]
# Colab notebooks execute code on Google's cloud servers, meaning you can leverage the power of Google hardware, including [GPUs and TPUs](#using-accelerated-hardware), regardless of the power of your machine. All you need is a browser.
#
# For example, if you find yourself waiting for **pandas** code to finish running and want to go faster, you can switch to a GPU Runtime and use libraries like [RAPIDS cuDF](https://rapids.ai/cudf-pandas) that provide zero-code-change acceleration.

# %% [markdown]
# To learn more about accelerating pandas on Colab, see the [10 minute guide](https://colab.research.google.com/github/rapidsai-community/showcase/blob/main/getting_started_tutorials/cudf_pandas_colab_demo.ipynb) or
#  [US stock market data analysis demo](https://colab.research.google.com/github/rapidsai-community/showcase/blob/main/getting_started_tutorials/cudf_pandas_stocks_demo.ipynb).

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Machine learning
# </div>
#
# With Colab you can import an image dataset, train an image classifier on it, and evaluate the model, all in just [a few lines of code](https://colab.research.google.com/github/tensorflow/docs/blob/master/site/en/tutorials/quickstart/beginner.ipynb).

# %% [markdown]
# Colab is used extensively in the machine learning community with applications including:
# - Getting started with TensorFlow
# - Developing and training neural networks
# - Experimenting with TPUs
# - Disseminating AI research
# - Creating tutorials
#
# To see sample Colab notebooks that demonstrate machine learning applications, see the [machine learning examples](#machine-learning-examples) below.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## More Resources
#
# ### Working with Notebooks in Colab
#
# </div>
#
# - [Overview of Colab](/notebooks/basic_features_overview.ipynb)
# - [Guide to Markdown](/notebooks/markdown_guide.ipynb)
# - [Importing libraries and installing dependencies](/notebooks/snippets/importing_libraries.ipynb)
# - [Saving and loading notebooks in GitHub](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/colab-github-demo.ipynb)
# - [Interactive forms](/notebooks/forms.ipynb)
# - [Interactive widgets](/notebooks/widgets.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="working-with-data"></a>
# ### Working with Data
# </div>
#
# - [Loading data: Drive, Sheets, and Google Cloud Storage](/notebooks/io.ipynb)
# - [Charts: visualizing data](/notebooks/charts.ipynb)
# - [Getting started with BigQuery](/notebooks/bigquery.ipynb)
#
# <div class="markdown-google-sans">
#
# ### Machine Learning
#
# <div>
#
# These are a few of the notebooks related to Machine Learning, including Google's online Machine Learning course. See the [full course website](https://developers.google.com/machine-learning/crash-course/) for more.
# - [Intro to Pandas DataFrame](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/pandas_dataframe_ultraquick_tutorial.ipynb)
# - [Intro to RAPIDS cuDF to accelerate pandas](https://nvda.ws/rapids-cudf)
# - [Getting Started with cuML's accelerator mode](https://colab.research.google.com/github/rapidsai-community/showcase/blob/main/getting_started_tutorials/cuml_sklearn_colab_demo.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="using-accelerated-hardware"></a>
# ### Using Accelerated Hardware
# </div>
#
# - [Train a CNN to classify handwritten digits on the MNIST dataset using Flax NNX API](https://colab.research.google.com/github/google/flax/blob/main/docs_nnx/mnist_tutorial.ipynb)
# - [Train a Vision Transformer (ViT) for image classification with JAX](https://colab.research.google.com/github/jax-ml/jax-ai-stack/blob/main/docs/source/JAX_Vision_transformer.ipynb)
# - [Text classification with a transformer language model using JAX](https://colab.research.google.com/github/jax-ml/jax-ai-stack/blob/main/docs/source/JAX_transformer_text_classification.ipynb)

# %% [markdown]
# <div class="markdown-google-sans">
#
# <a name="machine-learning-examples"></a>
#
# ### Featured examples
#
# </div>
#
# - [Train a miniGPT language model with JAX AI Stack](https://docs.jaxstack.ai/en/latest/JAX_for_LLM_pretraining.html)
# - [LoRA/QLoRA finetuning for LLM using Tunix](https://github.com/google/tunix/blob/main/examples/qlora_gemma.ipynb)
# - [Parameter-efficient fine-tuning of Gemma with LoRA and QLoRA](https://keras.io/examples/keras_recipes/parameter_efficient_finetuning_of_gemma_with_lora_and_qlora/)
# - [Loading Hugging Face Transformers Checkpoints](https://keras.io/keras_hub/guides/hugging_face_keras_integration/)
# - [8-bit Integer Quantization in Keras](https://keras.io/guides/int8_quantization_in_keras/)
# - [Float8 training and inference with a simple Transformer model](https://keras.io/examples/keras_recipes/float8_training_and_inference_with_transformer/)
# - [Pretraining a Transformer from scratch with KerasHub](https://keras.io/keras_hub/guides/transformer_pretraining/)
# - [Simple MNIST convnet](https://keras.io/examples/vision/mnist_convnet/)
# - [Image classification from scratch using Keras 3](https://keras.io/examples/vision/image_classification_from_scratch/)
# - [Image Classification with KerasHub](https://keras.io/keras_hub/guides/classification_with_keras_hub/)

# %%
# !pip install -U byaldi pdf2image
# !apt-get install -y poppler-utils
# Out:
# Collecting byaldi
#   Downloading Byaldi-0.0.7-py3-none-any.whl.metadata (20 kB)
# Collecting pdf2image
#   Downloading pdf2image-1.17.0-py3-none-any.whl.metadata (6.2 kB)
# Collecting colpali-engine<0.4.0,>=0.3.4 (from byaldi)
#   Downloading colpali_engine-0.3.15-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.12/dist-packages (from byaldi) (0.5.4)
# Collecting mteb==1.6.35 (from byaldi)
#   Downloading mteb-1.6.35-py3-none-any.whl.metadata (23 kB)
# Collecting ninja (from byaldi)
#   Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: srsly in /usr/local/lib/python3.12/dist-packages (from byaldi) (2.5.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from byaldi) (2.10.0+cu128)
# Requirement already satisfied: transformers>=4.42.0 in /usr/local/lib/python3.12/dist-packages (from byaldi) (5.0.0)
# Requirement already satisfied: datasets>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from mteb==1.6.35->byaldi) (4.0.0)
# Collecting jsonlines (from mteb==1.6.35->byaldi)
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mteb==1.6.35->byaldi) (2.0.2)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from mteb==1.6.35->byaldi) (2.32.4)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from mteb==1.6.35->byaldi) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mteb==1.6.35->byaldi) (1.16.3)
# Requirement already satisfied: sentence-transformers>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from mteb==1.6.35->byaldi) (5.3.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from mteb==1.6.35->byaldi) (4.67.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from mteb==1.6.35->byaldi) (13.9.4)
# Collecting pytrec-eval-terrier>=0.5.6 (from mteb==1.6.35->byaldi)
#   Downloading pytrec_eval_terrier-0.5.10-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.12/dist-packages (from mteb==1.6.35->byaldi) (2.12.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from mteb==1.6.35->byaldi) (4.15.0)
# Collecting eval-type-backport (from mteb==1.6.35->byaldi)
#   Downloading eval_type_backport-0.3.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from pdf2image) (11.3.0)
# Requirement already satisfied: peft<0.19.0,>=0.18.0 in /usr/local/lib/python3.12/dist-packages (from colpali-engine<0.4.0,>=0.3.4->byaldi) (0.18.1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from colpali-engine<0.4.0,>=0.3.4->byaldi) (0.25.0+cu128)
# Collecting transformers>=4.42.0 (from byaldi)
#   Downloading transformers-5.5.0-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->byaldi) (3.25.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->byaldi) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->byaldi) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->byaldi) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->byaldi) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->byaldi) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->byaldi) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->byaldi) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->byaldi) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->byaldi) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->byaldi) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->byaldi) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch->byaldi) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch->byaldi) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch->byaldi) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->byaldi) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->byaldi) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->byaldi) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->byaldi) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->byaldi) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->byaldi) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch->byaldi) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch->byaldi) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch->byaldi) (1.5.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.42.0->byaldi) (1.8.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.42.0->byaldi) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.42.0->byaldi) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.42.0->byaldi) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.42.0->byaldi) (0.22.2)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from transformers>=4.42.0->byaldi) (0.24.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.42.0->byaldi) (0.7.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from srsly->byaldi) (2.0.10)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.2.0->mteb==1.6.35->byaldi) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.2.0->mteb==1.6.35->byaldi) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets>=2.2.0->mteb==1.6.35->byaldi) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets>=2.2.0->mteb==1.6.35->byaldi) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.2.0->mteb==1.6.35->byaldi) (0.70.16)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers>=4.42.0->byaldi) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers>=4.42.0->byaldi) (0.28.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from peft<0.19.0,>=0.18.0->colpali-engine<0.4.0,>=0.3.4->byaldi) (5.9.5)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from peft<0.19.0,>=0.18.0->colpali-engine<0.4.0,>=0.3.4->byaldi) (1.13.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->mteb==1.6.35->byaldi) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->mteb==1.6.35->byaldi) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->mteb==1.6.35->byaldi) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->mteb==1.6.35->byaldi) (2026.2.25)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0.2->mteb==1.6.35->byaldi) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0.2->mteb==1.6.35->byaldi) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->byaldi) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->byaldi) (3.0.3)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonlines->mteb==1.6.35->byaldi) (26.1.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->mteb==1.6.35->byaldi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic->mteb==1.6.35->byaldi) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic->mteb==1.6.35->byaldi) (0.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->mteb==1.6.35->byaldi) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->mteb==1.6.35->byaldi) (2.20.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->transformers>=4.42.0->byaldi) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers>=4.42.0->byaldi) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->transformers>=4.42.0->byaldi) (0.0.4)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.2.0->mteb==1.6.35->byaldi) (3.13.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers>=4.42.0->byaldi) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers>=4.42.0->byaldi) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers>=4.42.0->byaldi) (0.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->mteb==1.6.35->byaldi) (0.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets>=2.2.0->mteb==1.6.35->byaldi) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets>=2.2.0->mteb==1.6.35->byaldi) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets>=2.2.0->mteb==1.6.35->byaldi) (2025.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.2.0->mteb==1.6.35->byaldi) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.2.0->mteb==1.6.35->byaldi) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.2.0->mteb==1.6.35->byaldi) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.2.0->mteb==1.6.35->byaldi) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.2.0->mteb==1.6.35->byaldi) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.2.0->mteb==1.6.35->byaldi) (1.23.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.2.0->mteb==1.6.35->byaldi) (1.17.0)
# Downloading Byaldi-0.0.7-py3-none-any.whl (21 kB)
# Downloading mteb-1.6.35-py3-none-any.whl (517 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 517.9/517.9 kB 42.4 MB/s eta 0:00:00
# Downloading pdf2image-1.17.0-py3-none-any.whl (11 kB)
# Downloading colpali_engine-0.3.15-py3-none-any.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.8/108.8 kB 12.9 MB/s eta 0:00:00
# Downloading transformers-5.5.0-py3-none-any.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 90.9 MB/s eta 0:00:00
# Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (180 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 18.7 MB/s eta 0:00:00
# Downloading pytrec_eval_terrier-0.5.10-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (304 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.8/304.8 kB 34.0 MB/s eta 0:00:00
# Downloading eval_type_backport-0.3.1-py3-none-any.whl (6.1 kB)
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Installing collected packages: pdf2image, ninja, jsonlines, eval-type-backport, pytrec-eval-terrier, transformers, mteb, colpali-engine, byaldi
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.0.0
#     Uninstalling transformers-5.0.0:
#       Successfully uninstalled transformers-5.0.0
# Successfully installed byaldi-0.0.7 colpali-engine-0.3.15 eval-type-backport-0.3.1 jsonlines-4.0.0 mteb-1.6.35 ninja-1.13.0 pdf2image-1.17.0 pytrec-eval-terrier-0.5.10 transformers-5.5.0
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 42 not upgraded.
# Need to get 186 kB of archives.
# After this operation, 697 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 poppler-utils amd64 22.02.0-2ubuntu0.12 [186 kB]
# Fetched 186 kB in 1s (134 kB/s)
# Selecting previously unselected package poppler-utils.
# (Reading database ... 122354 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_22.02.0-2ubuntu0.12_amd64.deb ...
# Unpacking poppler-utils (22.02.0-2ubuntu0.12) ...
# Setting up poppler-utils (22.02.0-2ubuntu0.12) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
from byaldi import RAGMultiModalModel

# This model treats each PDF page as an image to preserve tables and charts.
RAG = RAGMultiModalModel.from_pretrained("vidore/colpali-v1.2")
# Out:
# Verbosity is set to 1 (active). Pass verbose=0 to make quieter.
# adapter_config.json:   0%|          | 0.00/750 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/605 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_932/1340784561.py in <cell line: 0>()
#       2
#       3 # This model treats each PDF page as an image to preserve tables and charts.
# ----> 4 RAG = RAGMultiModalModel.from_pretrained("vidore/colpali-v1.2")
#
# /usr/local/lib/python3.12/dist-packages/byaldi/RAGModel.py in from_pretrained(cls, pretrained_model_name_or_path, index_root, device, verbose)
#      57         """
#      58         instance = cls()
# ---> 59         instance.model = ColPaliModel.from_pretrained(
#      60             pretrained_model_name_or_path,
#      61             index_root=index_root,
#
# /usr/local/lib/python3.12/dist-packages/byaldi/colpali.py in from_pretrained(cls, pretrained_model_name_or_path, n_gpu, verbose, device, index_root, **kwargs)
#     207         **kwargs,
#     208     ):
# --> 209         return cls(
#     210             pretrained_model_name_or_path=pretrained_model_name_or_path,
#     211             n_gpu=n_gpu,
#
# /usr/local/lib/python3.12/dist-packages/byaldi/colpali.py in __init__(self, pretrained_model_name_or_path, n_gpu, index_name, verbose, load_from_index, index_root, device, **kwargs)
#      67
#      68         if "colpali" in pretrained_model_name_or_path.lower():
# ---> 69             self.model = ColPali.from_pretrained(
#      70                 self.pretrained_model_name_or_path,
#      71                 torch_dtype=torch.bfloat16,
#
# /usr/local/lib/python3.12/dist-packages/colpali_engine/models/paligemma/colpali/modeling_colpali.py in from_pretrained(cls, *args, **kwargs)
#      36         if key_mapping is None:
#      37             key_mapping = cls._checkpoint_conversion_mapping
# ---> 38         return super().from_pretrained(*args, **kwargs, key_mapping=key_mapping)
#      39
#      40     def __init__(self, config: PaliGemmaConfig, mask_non_image_embeddings: bool = False):
#
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4161             if token is not None:
#    4162                 adapter_kwargs["token"] = token
# -> 4163             loading_info = model.load_adapter(
#    4164                 _adapter_model_path,
#    4165                 adapter_name=adapter_name,
#
# /usr/local/lib/python3.12/dist-packages/transformers/integrations/peft.py in load_adapter(self, peft_model_id, adapter_name, peft_config, adapter_state_dict, low_cpu_mem_usage, is_trainable, hotswap, local_files_only, adapter_kwargs, load_config, **kwargs)
#     562
#     563         # TODO: remove once PEFT < 0.19 is dropped, use peft.utils.transformers_weight_conversion
# --> 564         peft_config = convert_peft_config_for_transformers(peft_config, model=self, conversions=weight_conversions)
#     565
#     566         if hasattr(peft_config, "inference_mode"):
#
# /usr/local/lib/python3.12/dist-packages/transformers/integrations/peft.py in convert_peft_config_for_transformers(peft_config, model, conversions)
#    1113     model_type = getattr(model.config, "model_type", None)
#    1114     if get_checkpoint_conversion_mapping(model_type) is not None:
# -> 1115         peft_config = _convert_peft_config_moe(peft_config, model_type)
#    1116
#    1117     return peft_config
#
# /usr/local/lib/python3.12/dist-packages/transformers/integrations/peft.py in _convert_peft_config_moe(peft_config, model_type)
#    1036         return peft_config
#    1037
# -> 1038     target_module_mapping = _MOE_TARGET_MODULE_MAPPING[base_model_type]
#    1039     fused_targets = _MOE_FUSED_TARGETS.get(base_model_type, {})
#    1040
#
# KeyError: 'llava'

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# 1. Uninstall broken versions
# !pip uninstall -y numpy transformers peft byaldi colpali-engine

# 2. Install the "Golden Match" stable versions
# !pip install "numpy<2.0" transformers==4.45.0 peft==0.11.1 byaldi==0.0.4 colpali-engine==0.3.1
# !pip install pdf2image datasets
# !apt-get install -y poppler-utils
# Out:
# Found existing installation: numpy 2.0.2
# Uninstalling numpy-2.0.2:
#   Successfully uninstalled numpy-2.0.2
# Found existing installation: transformers 5.5.0
# Uninstalling transformers-5.5.0:
#   Successfully uninstalled transformers-5.5.0
# Found existing installation: peft 0.18.1
# Uninstalling peft-0.18.1:
#   Successfully uninstalled peft-0.18.1
# Found existing installation: Byaldi 0.0.7
# Uninstalling Byaldi-0.0.7:
#   Successfully uninstalled Byaldi-0.0.7
# Found existing installation: colpali_engine 0.3.15
# Uninstalling colpali_engine-0.3.15:
#   Successfully uninstalled colpali_engine-0.3.15
# Collecting numpy<2.0
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 5.5 MB/s eta 0:00:00
# Collecting transformers==4.45.0
#   Downloading transformers-4.45.0-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 4.7 MB/s eta 0:00:00
# Collecting peft==0.11.1
#   Downloading peft-0.11.1-py3-none-any.whl.metadata (13 kB)
# Collecting byaldi==0.0.4
#   Downloading Byaldi-0.0.4-py3-none-any.whl.metadata (20 kB)
# Collecting colpali-engine==0.3.1
#   Downloading colpali_engine-0.3.1-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers==4.45.0) (3.25.2)
# Collecting huggingface-hub<1.0,>=0.23.2 (from transformers==4.45.0)
#   Downloading huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.45.0) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.45.0) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.45.0) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers==4.45.0) (2.32.4)
# Collecting tokenizers<0.21,>=0.20 (from transformers==4.45.0)
#   Downloading tokenizers-0.20.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.45.0) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers==4.45.0) (4.67.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from peft==0.11.1) (5.9.5)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from peft==0.11.1) (2.10.0+cu128)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from peft==0.11.1) (1.13.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.12/dist-packages (from byaldi==0.0.4) (0.5.4)
# Requirement already satisfied: mteb==1.6.35 in /usr/local/lib/python3.12/dist-packages (from byaldi==0.0.4) (1.6.35)
# Requirement already satisfied: ninja in /usr/local/lib/python3.12/dist-packages (from byaldi==0.0.4) (1.13.0)
# Requirement already satisfied: pdf2image in /usr/local/lib/python3.12/dist-packages (from byaldi==0.0.4) (1.17.0)
# Requirement already satisfied: srsly in /usr/local/lib/python3.12/dist-packages (from byaldi==0.0.4) (2.5.3)
# Collecting gputil (from colpali-engine==0.3.1)
#   Downloading GPUtil-1.4.0.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pillow<11.0.0,>=9.2.0 (from colpali-engine==0.3.1)
#   Downloading pillow-10.4.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Requirement already satisfied: datasets>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from mteb==1.6.35->byaldi==0.0.4) (4.0.0)
# Requirement already satisfied: jsonlines in /usr/local/lib/python3.12/dist-packages (from mteb==1.6.35->byaldi==0.0.4) (4.0.0)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from mteb==1.6.35->byaldi==0.0.4) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mteb==1.6.35->byaldi==0.0.4) (1.16.3)
# Requirement already satisfied: sentence-transformers>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from mteb==1.6.35->byaldi==0.0.4) (5.3.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from mteb==1.6.35->byaldi==0.0.4) (13.9.4)
# Requirement already satisfied: pytrec-eval-terrier>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from mteb==1.6.35->byaldi==0.0.4) (0.5.10)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.12/dist-packages (from mteb==1.6.35->byaldi==0.0.4) (2.12.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from mteb==1.6.35->byaldi==0.0.4) (4.15.0)
# Requirement already satisfied: eval-type-backport in /usr/local/lib/python3.12/dist-packages (from mteb==1.6.35->byaldi==0.0.4) (0.3.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.45.0) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.45.0) (1.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.45.0) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.45.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.45.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.45.0) (2026.2.25)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.11.1) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.11.1) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.11.1) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.11.1) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.11.1) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.11.1) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.11.1) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.11.1) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.11.1) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.11.1) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.11.1) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.11.1) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.11.1) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.11.1) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.11.1) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.11.1) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.11.1) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.11.1) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.11.1) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.11.1) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.11.1) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.13.0->peft==0.11.1) (1.5.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from srsly->byaldi==0.0.4) (2.0.10)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.2.0->mteb==1.6.35->byaldi==0.0.4) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.2.0->mteb==1.6.35->byaldi==0.0.4) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets>=2.2.0->mteb==1.6.35->byaldi==0.0.4) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets>=2.2.0->mteb==1.6.35->byaldi==0.0.4) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.2.0->mteb==1.6.35->byaldi==0.0.4) (0.70.16)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0.2->mteb==1.6.35->byaldi==0.0.4) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0.2->mteb==1.6.35->byaldi==0.0.4) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.13.0->peft==0.11.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.13.0->peft==0.11.1) (3.0.3)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonlines->mteb==1.6.35->byaldi==0.0.4) (26.1.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->mteb==1.6.35->byaldi==0.0.4) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic->mteb==1.6.35->byaldi==0.0.4) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic->mteb==1.6.35->byaldi==0.0.4) (0.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->mteb==1.6.35->byaldi==0.0.4) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->mteb==1.6.35->byaldi==0.0.4) (2.20.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.2.0->mteb==1.6.35->byaldi==0.0.4) (3.13.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->mteb==1.6.35->byaldi==0.0.4) (0.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets>=2.2.0->mteb==1.6.35->byaldi==0.0.4) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets>=2.2.0->mteb==1.6.35->byaldi==0.0.4) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets>=2.2.0->mteb==1.6.35->byaldi==0.0.4) (2025.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.2.0->mteb==1.6.35->byaldi==0.0.4) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.2.0->mteb==1.6.35->byaldi==0.0.4) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.2.0->mteb==1.6.35->byaldi==0.0.4) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.2.0->mteb==1.6.35->byaldi==0.0.4) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.2.0->mteb==1.6.35->byaldi==0.0.4) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.2.0->mteb==1.6.35->byaldi==0.0.4) (1.23.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.2.0->mteb==1.6.35->byaldi==0.0.4) (1.17.0)
# Downloading transformers-4.45.0-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 126.4 MB/s eta 0:00:00
# Downloading peft-0.11.1-py3-none-any.whl (251 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.6/251.6 kB 29.9 MB/s eta 0:00:00
# Downloading Byaldi-0.0.4-py3-none-any.whl (20 kB)
# Downloading colpali_engine-0.3.1-py3-none-any.whl (32 kB)
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 93.8 MB/s eta 0:00:00
# Downloading huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 51.8 MB/s eta 0:00:00
# Downloading pillow-10.4.0-cp312-cp312-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 136.4 MB/s eta 0:00:00
# Downloading tokenizers-0.20.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 121.3 MB/s eta 0:00:00
# Building wheels for collected packages: gputil
#   Building wheel for gputil (setup.py) ... done
#   Created wheel for gputil: filename=GPUtil-1.4.0-py3-none-any.whl size=7392 sha256=f91fa8a24081ed0766bbc1c051df992c7811e5d0e713f2199595cf85f564cbfc
#   Stored in directory: /root/.cache/pip/wheels/92/a8/b7/d8a067c31a74de9ca252bbe53dea5f896faabd25d55f541037
# Successfully built gputil
# Installing collected packages: gputil, pillow, numpy, huggingface-hub, tokenizers, transformers, peft, colpali-engine, byaldi
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.3.0
#     Uninstalling pillow-11.3.0:
#       Successfully uninstalled pillow-11.3.0
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.8.0
#     Uninstalling huggingface_hub-1.8.0:
#       Successfully uninstalled huggingface_hub-1.8.0
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.22.2
#     Uninstalling tokenizers-0.22.2:
#       Successfully uninstalled tokenizers-0.22.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# tobler 0.13.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# pytensor 2.38.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# cupy-cuda12x 14.0.1 requires numpy<2.6,>=2.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed byaldi-0.0.4 colpali-engine-0.3.1 gputil-1.4.0 huggingface-hub-0.36.2 numpy-1.26.4 peft-0.11.1 pillow-10.4.0 tokenizers-0.20.3 transformers-4.45.0
# Requirement already satisfied: pdf2image in /usr/local/lib/python3.12/dist-packages (1.17.0)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from pdf2image) (10.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets) (3.25.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets) (4.67.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.36.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.13.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (1.4.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2026.2.25)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.23.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# poppler-utils is already the newest version (22.02.0-2ubuntu0.12).
# 0 upgraded, 0 newly installed, 0 to remove and 42 not upgraded.

# %%
import os
import base64
from huggingface_hub import login
from byaldi import RAGMultiModalModel
from pdf2image import convert_from_path
from IPython.display import Image, display

# --- A. SECURE AUTHENTICATION ---
# Replace with your hf_... token
login(token="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")

# --- B. INITIALIZE VISION ENGINE ---
# We use ColPali v1.2: the state-of-the-art for 'seeing' documents.
print("Initializing ColPali v1.2 Engine...")
RAG = RAGMultiModalModel.from_pretrained("vidore/colpali-v1.2")

# --- C. DOCUMENT INGESTION PIPELINE ---
# This converts your uploaded PDFs into high-res images for the AI
input_folder = "my_docs"
processed_folder = "processed_visuals"

if not os.path.exists(processed_folder):
    os.makedirs(processed_folder)

print("Reading and converting your documents...")
pdf_files = [f for f in os.listdir(input_folder) if f.endswith('.pdf')]

if not pdf_files:
    print("CRITICAL ERROR: No PDFs found in 'my_docs'. Please upload files first!")
else:
    for pdf in pdf_files:
        pages = convert_from_path(os.path.join(input_folder, pdf))
        for i, page in enumerate(pages):
            page.save(f"{processed_folder}/{pdf}_page_{i}.png", "PNG")

    # --- D. MULTI-VECTOR INDEXING ---
    # This creates the 'Late Interaction' map of your visual data.
    print(f"Building Visual Index for {len(os.listdir(processed_folder))} pages...")
    RAG.index(
        input_path=processed_folder,
        index_name="insightparse_final_index",
        store_collection_with_index=True,
        overwrite=True
    )

    # --- E. INTELLIGENT RETRIEVAL TEST ---
    # We query for a visual element to prove the engine's 'Spatial Awareness'.
    query = "Find a page with a complex data table, financial chart, or technical diagram."
    results = RAG.search(query, k=1)

    # --- F. OUTPUT GENERATION ---
    image_data = base64.b64decode(results[0].base64)
    with open("final_submission_result.jpg", "wb") as f:
        f.write(image_data)

    print("\n--- PROJECT SUCCESS: INSIGHTPARSE ENGINE COMPLETE ---")
    display(Image("final_submission_result.jpg"))
# Out:
# Initializing ColPali v1.2 Engine...
# Verbosity is set to 1 (active). Pass verbose=0 to make quieter.
# `config.hidden_act` is ignored, you should use `config.hidden_activation` instead.
# Gemma's activation function will be set to `gelu_pytorch_tanh`. Please, use
# `config.hidden_activation` if you want to override this behaviour.
# See https://github.com/huggingface/transformers/pull/29402 for more details.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# adapter_model.safetensors:   0%|          | 0.00/78.6M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/700 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.8M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/733 [00:00<?, ?B/s]
# Reading and converting your documents...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_11252/3070243779.py in <cell line: 0>()
#      24
#      25 print("Reading and converting your documents...")
# ---> 26 pdf_files = [f for f in os.listdir(input_folder) if f.endswith('.pdf')]
#      27
#      28 if not pdf_files:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'my_docs'

# %%
import os
import base64
from huggingface_hub import login
from byaldi import RAGMultiModalModel
from pdf2image import convert_from_path
from IPython.display import Image, display

# --- 1. SECURE AUTHENTICATION ---
# Use the token you just created with 'Read' permissions
login(token="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")

# --- 2. INITIALIZE VISION ENGINE ---
# Loading ColPali v1.2 - The 'eyes' of the InsightParse system
print("Initializing ColPali v1.2 Engine...")
RAG = RAGMultiModalModel.from_pretrained("vidore/colpali-v1.2")

# --- 3. UPDATED DOCUMENT PIPELINE ---
# Using the absolute path from your Colab sidebar to fix the FileNotFoundError
input_folder = "/content/media/my_docs"
processed_folder = "processed_visuals"

if not os.path.exists(processed_folder):
    os.makedirs(processed_folder)

print(f"Reading documents from: {input_folder}")
pdf_files = [f for f in os.listdir(input_folder) if f.endswith('.pdf')]

if not pdf_files:
    print("CRITICAL ERROR: No PDFs found! Please check the folder in your sidebar.")
else:
    print(f"Found {len(pdf_files)} PDFs. Converting to visual patches...")
    for pdf in pdf_files:
        # Convert PDF pages to images for Multi-Modal processing
        pages = convert_from_path(os.path.join(input_folder, pdf))
        for i, page in enumerate(pages):
            page.save(f"{processed_folder}/{pdf}_page_{i}.png", "PNG")

    # --- 4. MULTI-VECTOR INDEXING ---
    # Creating the 'Late Interaction' index to preserve spatial context
    print(f"Building Visual Index for {len(os.listdir(processed_folder))} pages...")
    RAG.index(
        input_path=processed_folder,
        index_name="insightparse_final_index",
        store_collection_with_index=True,
        overwrite=True
    )

    # --- 5. THE FINAL TEST QUERY ---
    # We ask for a complex chart from the NVIDIA or Google 10-K files
    query = "Find a page with a detailed financial table or a technical GPU architecture diagram."
    results = RAG.search(query, k=1)

    # --- 6. GENERATE FINAL OUTPUT ---
    image_data = base64.b64decode(results[0].base64)
    with open("final_submission_result.jpg", "wb") as f:
        f.write(image_data)

    print("\n--- PROJECT SUCCESS: INSIGHTPARSE ENGINE IS LIVE ---")
    display(Image("final_submission_result.jpg"))
# Out:
# Initializing ColPali v1.2 Engine...
# Verbosity is set to 1 (active). Pass verbose=0 to make quieter.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Reading documents from: /content/media/my_docs
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_11252/1224301358.py in <cell line: 0>()
#      24
#      25 print(f"Reading documents from: {input_folder}")
# ---> 26 pdf_files = [f for f in os.listdir(input_folder) if f.endswith('.pdf')]
#      27
#      28 if not pdf_files:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/media/my_docs'

# %%
import os
import base64
from huggingface_hub import login
from byaldi import RAGMultiModalModel
from pdf2image import convert_from_path
from IPython.display import Image, display

# --- 1. SECURE AUTHENTICATION ---
# Use the token you just created with 'Read' permissions
login(token="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")

# --- 2. INITIALIZE VISION ENGINE ---
# Loading ColPali v1.2 - The 'eyes' of the InsightParse system
print("Initializing ColPali v1.2 Engine...")
RAG = RAGMultiModalModel.from_pretrained("vidore/colpali-v1.2")

# --- 3. UPDATED DOCUMENT PIPELINE ---
# Using the absolute path from your Colab sidebar to fix the FileNotFoundError
input_folder = "/content/media/my_docs"
processed_folder = "processed_visuals"

if not os.path.exists(processed_folder):
    os.makedirs(processed_folder)

print(f"Reading documents from: {input_folder}")
pdf_files = [f for f in os.listdir(input_folder) if f.endswith('.pdf')]

if not pdf_files:
    print("CRITICAL ERROR: No PDFs found! Please check the folder in your sidebar.")
else:
    print(f"Found {len(pdf_files)} PDFs. Converting to visual patches...")
    for pdf in pdf_files:
        # Convert PDF pages to images for Multi-Modal processing
        pages = convert_from_path(os.path.join(input_folder, pdf))
        for i, page in enumerate(pages):
            page.save(f"{processed_folder}/{pdf}_page_{i}.png", "PNG")

    # --- 4. MULTI-VECTOR INDEXING ---
    # Creating the 'Late Interaction' index to preserve spatial context
    print(f"Building Visual Index for {len(os.listdir(processed_folder))} pages...")
    RAG.index(
        input_path=processed_folder,
        index_name="insightparse_final_index",
        store_collection_with_index=True,
        overwrite=True
    )

    # --- 5. THE FINAL TEST QUERY ---
    # We ask for a complex chart from the NVIDIA or Google 10-K files
    query = "Find a page with a detailed financial table or a technical GPU architecture diagram."
    results = RAG.search(query, k=1)

    # --- 6. GENERATE FINAL OUTPUT ---
    image_data = base64.b64decode(results[0].base64)
    with open("final_submission_result.jpg", "wb") as f:
        f.write(image_data)

    print("\n--- PROJECT SUCCESS: INSIGHTPARSE ENGINE IS LIVE ---")
    display(Image("final_submission_result.jpg"))
# Out:
# Initializing ColPali v1.2 Engine...
# Verbosity is set to 1 (active). Pass verbose=0 to make quieter.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Reading documents from: /content/media/my_docs
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_11252/4067933254.py in <cell line: 0>()
#      24
#      25 print(f"Reading documents from: {input_folder}")
# ---> 26 pdf_files = [f for f in os.listdir(input_folder) if f.endswith('.pdf')]
#      27
#      28 if not pdf_files:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/media/my_docs'

# %%
import os
# This searches your entire server for the 'my_docs' folder
for root, dirs, files in os.walk('/'):
    if 'my_docs' in dirs:
        print(f"FOUND IT! The exact path is: {os.path.join(root, 'my_docs')}")
        break
# Out:
# FOUND IT! The exact path is: /media/my_docs

# %%
import os
import base64
from huggingface_hub import login
from byaldi import RAGMultiModalModel
from pdf2image import convert_from_path
from IPython.display import Image, display

# 1. SECURE AUTHENTICATION
# Paste your token from Hugging Face here
login(token="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")

# 2. INITIALIZE VISION ENGINE
print("Initializing ColPali v1.2 Engine...")
RAG = RAGMultiModalModel.from_pretrained("vidore/colpali-v1.2")

# 3. DOCUMENT INGESTION PIPELINE
# Using the absolute path we discovered: /media/my_docs
input_folder = "/media/my_docs"
processed_folder = "processed_visuals"

if not os.path.exists(processed_folder):
    os.makedirs(processed_folder)

print(f"Reading documents from: {input_folder}")
pdf_files = [f for f in os.listdir(input_folder) if f.endswith('.pdf')]

if not pdf_files:
    print("ERROR: No PDFs found! Double check the files in /media/my_docs")
else:
    for pdf in pdf_files:
        print(f"Converting {pdf} to visual patches...")
        pages = convert_from_path(os.path.join(input_folder, pdf))
        for i, page in enumerate(pages):
            page.save(f"{processed_folder}/{pdf}_page_{i}.png", "PNG")

    # 4. BUILDING THE VISUAL INDEX
    print(f"Building Visual Index for {len(os.listdir(processed_folder))} pages...")
    RAG.index(
        input_path=processed_folder,
        index_name="insight_parse_final",
        store_collection_with_index=True,
        overwrite=True
    )

    # 5. THE SEARCH QUERY
    # We ask for a visual element to prove the AI "sees" your NVIDIA/Google charts
    query = "Find a page with a complex data table, financial chart, or technical diagram."
    results = RAG.search(query, k=1)

    # 6. GENERATE FINAL OUTPUT
    image_data = base64.b64decode(results[0].base64)
    with open("final_submission_result.jpg", "wb") as f:
        f.write(image_data)

    print("\n--- PROJECT SUCCESS: INSIGHTPARSE ENGINE IS LIVE ---")
    display(Image("final_submission_result.jpg"))
# Out:
# Initializing ColPali v1.2 Engine...
# Verbosity is set to 1 (active). Pass verbose=0 to make quieter.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Reading documents from: /media/my_docs
# Converting nvidia_h100_tensor_core_gpu_datasheet.pdf to visual patches...
# Converting GOOG-10-K-2025.pdf to visual patches...
# Converting NVIDIA H100 GPU Whitepaper.pdf to visual patches...
# Converting Onsite Search_ Find What You Seek _ NVIDIA.pdf to visual patches...
# Building Visual Index for 176 pages...
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_51.png
# Starting from v4.46, the `logits` model output will have the same type as the model (except at train time, where it will always be FP32)
# Added page 1 of document 0 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_36.png
# Added page 1 of document 1 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_43.png
# Added page 1 of document 2 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/Onsite Search_ Find What You Seek _ NVIDIA.pdf_page_2.png
# Added page 1 of document 3 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_37.png
# Added page 1 of document 4 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_8.png
# Added page 1 of document 5 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_41.png
# Added page 1 of document 6 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_14.png
# Added page 1 of document 7 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_60.png
# Added page 1 of document 8 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_73.png
# Added page 1 of document 9 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_78.png
# Added page 1 of document 10 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_27.png
# Added page 1 of document 11 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_55.png
# Added page 1 of document 12 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_34.png
# Added page 1 of document 13 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_85.png
# Added page 1 of document 14 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_66.png
# Added page 1 of document 15 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_50.png
# Added page 1 of document 16 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_58.png
# Added page 1 of document 17 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_21.png
# Added page 1 of document 18 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_89.png
# Added page 1 of document 19 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_9.png
# Added page 1 of document 20 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_8.png
# Added page 1 of document 21 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_31.png
# Added page 1 of document 22 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_7.png
# Added page 1 of document 23 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_75.png
# Added page 1 of document 24 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_59.png
# Added page 1 of document 25 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_18.png
# Added page 1 of document 26 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_97.png
# Added page 1 of document 27 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_95.png
# Added page 1 of document 28 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_91.png
# Added page 1 of document 29 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_3.png
# Added page 1 of document 30 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_72.png
# Added page 1 of document 31 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_49.png
# Added page 1 of document 32 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/nvidia_h100_tensor_core_gpu_datasheet.pdf_page_2.png
# Added page 1 of document 33 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_16.png
# Added page 1 of document 34 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_47.png
# Added page 1 of document 35 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_0.png
# Added page 1 of document 36 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_77.png
# Added page 1 of document 37 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_27.png
# Added page 1 of document 38 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_1.png
# Added page 1 of document 39 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_32.png
# Added page 1 of document 40 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_38.png
# Added page 1 of document 41 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_53.png
# Added page 1 of document 42 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_16.png
# Added page 1 of document 43 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_35.png
# Added page 1 of document 44 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/nvidia_h100_tensor_core_gpu_datasheet.pdf_page_1.png
# Added page 1 of document 45 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_44.png
# Added page 1 of document 46 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_68.png
# Added page 1 of document 47 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_42.png
# Added page 1 of document 48 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_59.png
# Added page 1 of document 49 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_66.png
# Added page 1 of document 50 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_30.png
# Added page 1 of document 51 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_50.png
# Added page 1 of document 52 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_92.png
# Added page 1 of document 53 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_67.png
# Added page 1 of document 54 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_0.png
# Added page 1 of document 55 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_12.png
# Added page 1 of document 56 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_13.png
# Added page 1 of document 57 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_44.png
# Added page 1 of document 58 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_68.png
# Added page 1 of document 59 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_10.png
# Added page 1 of document 60 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_76.png
# Added page 1 of document 61 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_81.png
# Added page 1 of document 62 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_2.png
# Added page 1 of document 63 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_57.png
# Added page 1 of document 64 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_96.png
# Added page 1 of document 65 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_49.png
# Added page 1 of document 66 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_33.png
# Added page 1 of document 67 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_71.png
# Added page 1 of document 68 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_22.png
# Added page 1 of document 69 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_46.png
# Added page 1 of document 70 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_5.png
# Added page 1 of document 71 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_54.png
# Added page 1 of document 72 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_58.png
# Added page 1 of document 73 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_19.png
# Added page 1 of document 74 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_88.png
# Added page 1 of document 75 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_28.png
# Added page 1 of document 76 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_79.png
# Added page 1 of document 77 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_9.png
# Added page 1 of document 78 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_98.png
# Added page 1 of document 79 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_14.png
# Added page 1 of document 80 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_60.png
# Added page 1 of document 81 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_29.png
# Added page 1 of document 82 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_24.png
# Added page 1 of document 83 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_64.png
# Added page 1 of document 84 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_26.png
# Added page 1 of document 85 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_74.png
# Added page 1 of document 86 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_83.png
# Added page 1 of document 87 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/nvidia_h100_tensor_core_gpu_datasheet.pdf_page_0.png
# Added page 1 of document 88 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_54.png
# Added page 1 of document 89 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_90.png
# Added page 1 of document 90 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_20.png
# Added page 1 of document 91 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_20.png
# Added page 1 of document 92 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_43.png
# Added page 1 of document 93 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_31.png
# Added page 1 of document 94 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_93.png
# Added page 1 of document 95 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_41.png
# Added page 1 of document 96 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_3.png
# Added page 1 of document 97 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_23.png
# Added page 1 of document 98 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_22.png
# Added page 1 of document 99 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_13.png
# Added page 1 of document 100 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_40.png
# Added page 1 of document 101 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/Onsite Search_ Find What You Seek _ NVIDIA.pdf_page_0.png
# Added page 1 of document 102 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_57.png
# Added page 1 of document 103 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_55.png
# Added page 1 of document 104 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_21.png
# Added page 1 of document 105 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_69.png
# Added page 1 of document 106 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_52.png
# Added page 1 of document 107 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_30.png
# Added page 1 of document 108 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_5.png
# Added page 1 of document 109 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_17.png
# Added page 1 of document 110 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_40.png
# Added page 1 of document 111 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_65.png
# Added page 1 of document 112 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_94.png
# Added page 1 of document 113 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_15.png
# Added page 1 of document 114 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_6.png
# Added page 1 of document 115 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_28.png
# Added page 1 of document 116 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_42.png
# Added page 1 of document 117 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_86.png
# Added page 1 of document 118 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_19.png
# Added page 1 of document 119 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_46.png
# Added page 1 of document 120 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_61.png
# Added page 1 of document 121 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_17.png
# Added page 1 of document 122 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_2.png
# Added page 1 of document 123 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_12.png
# Added page 1 of document 124 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_25.png
# Added page 1 of document 125 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_48.png
# Added page 1 of document 126 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_24.png
# Added page 1 of document 127 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_70.png
# Added page 1 of document 128 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_45.png
# Added page 1 of document 129 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_52.png
# Added page 1 of document 130 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_18.png
# Added page 1 of document 131 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_38.png
# Added page 1 of document 132 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_62.png
# Added page 1 of document 133 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/Onsite Search_ Find What You Seek _ NVIDIA.pdf_page_1.png
# Added page 1 of document 134 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_39.png
# Added page 1 of document 135 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_45.png
# Added page 1 of document 136 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_29.png
# Added page 1 of document 137 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_48.png
# Added page 1 of document 138 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_65.png
# Added page 1 of document 139 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_11.png
# Added page 1 of document 140 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_23.png
# Added page 1 of document 141 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_53.png
# Added page 1 of document 142 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_56.png
# Added page 1 of document 143 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_34.png
# Added page 1 of document 144 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_63.png
# Added page 1 of document 145 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_70.png
# Added page 1 of document 146 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_37.png
# Added page 1 of document 147 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_7.png
# Added page 1 of document 148 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_11.png
# Added page 1 of document 149 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_47.png
# Added page 1 of document 150 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_1.png
# Added page 1 of document 151 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_35.png
# Added page 1 of document 152 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_67.png
# Added page 1 of document 153 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_32.png
# Added page 1 of document 154 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_69.png
# Added page 1 of document 155 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_84.png
# Added page 1 of document 156 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_36.png
# Added page 1 of document 157 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_33.png
# Added page 1 of document 158 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_39.png
# Added page 1 of document 159 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_82.png
# Added page 1 of document 160 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_4.png
# Added page 1 of document 161 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_4.png
# Added page 1 of document 162 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_25.png
# Added page 1 of document 163 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_15.png
# Added page 1 of document 164 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_64.png
# Added page 1 of document 165 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_80.png
# Added page 1 of document 166 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_10.png
# Added page 1 of document 167 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_56.png
# Added page 1 of document 168 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_51.png
# Added page 1 of document 169 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_26.png
# Added page 1 of document 170 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_61.png
# Added page 1 of document 171 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_87.png
# Added page 1 of document 172 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_63.png
# Added page 1 of document 173 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/NVIDIA H100 GPU Whitepaper.pdf_page_6.png
# Added page 1 of document 174 to index.
# Index exported to .byaldi/insight_parse_final
# Indexing file: processed_visuals/GOOG-10-K-2025.pdf_page_62.png
# Added page 1 of document 175 to index.
# Index exported to .byaldi/insight_parse_final
# Index exported to .byaldi/insight_parse_final
#
# --- PROJECT SUCCESS: INSIGHTPARSE ENGINE IS LIVE ---

# %%
query = "What were Google's consolidated revenues for 2024 and 2025? Show me the table."
results = RAG.search(query, k=1)
display(Image(base64.b64decode(results[0].base64)))
